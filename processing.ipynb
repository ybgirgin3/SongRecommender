# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

# %%
filename = 'LITTLE BIG – FARADENZA (official music video).mp4'

# %%
plt.figure(figsize = (15,4))
data, sample_rate = librosa.load(filename, sr=22050, mono=True, offset=0.0, duration=50, res_type='kaiser_best')
librosa.display.waveplot(data, sr=sample_rate, max_points=50000.0, x_axis=True, offset = 0.0, max_sr = 1000)
# Out:
# /home/berkay/miniconda3/envs/dev/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ---------------------------------------------------------------------------
# ParameterError                            Traceback (most recent call last)
# /tmp/ipykernel_4938/3329773037.py in <module>
#       1 plt.figure(figsize = (15,4))
#       2 data, sample_rate = librosa.load(filename, sr=22050, mono=True, offset=0.0, duration=50, res_type='kaiser_best')
# ----> 3 librosa.display.waveplot(data, sr=sample_rate, max_points=50000.0, x_axis=True, offset = 0.0, max_sr = 1000)
#
# <decorator-gen-120> in waveplot(y, sr, max_points, x_axis, offset, max_sr, ax, **kwargs)
#
# ~/miniconda3/envs/dev/lib/python3.9/site-packages/librosa/util/decorators.py in __wrapper(func, *args, **kwargs)
#      54             lineno=code.co_firstlineno + 1,
#      55         )
# ...
